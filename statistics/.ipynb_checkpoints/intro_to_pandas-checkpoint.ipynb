# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\310295192\Desktop\series.csv')

# %%
df
# Out:
#        Value
# 0    1.20000
# 1    1.43200
# 2   15.64200
# 3  149.58400
# 4    0.94852

# %%
df*2
# Out:
#        Value
# 0    2.40000
# 1    2.86400
# 2   31.28400
# 3  299.16800
# 4    1.89704

# %%
ser = pd.Series(np.random.randn(4),name = 'daily returns')

# %%
ser.head()
# Out:
# 0    0.008104
# 1    0.736408
# 2    1.094814
# 3    0.520416
# Name: daily returns, dtype: float64

# %%
ser
# Out:
# 0    0.008104
# 1    0.736408
# 2    1.094814
# 3    0.520416
# Name: daily returns, dtype: float64

# %%
ser*10
# Out:
# 0     0.081037
# 1     7.364076
# 2    10.948140
# 3     5.204156
# Name: daily returns, dtype: float64

# %%
s.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3028cdf4ba8d> in <module>
# ----> 1 s.describe()
#
# NameError: name 's' is not defined

# %%
ser.describe()
# Out:
# count    4.000000
# mean     0.589935
# std      0.454503
# min      0.008104
# 25%      0.392338
# 50%      0.628412
# 75%      0.826009
# max      1.094814
# Name: daily returns, dtype: float64

# %%
ser
# Out:
# 0    0.008104
# 1    0.736408
# 2    1.094814
# 3    0.520416
# Name: daily returns, dtype: float64

# %%
ser.index=['Amazon','Google','Microsoft','Apple']

# %%
ser
# Out:
# Amazon       0.008104
# Google       0.736408
# Microsoft    1.094814
# Apple        0.520416
# Name: daily returns, dtype: float64

# %%
ser['Amazon']
# Out:
# 0.008103720458231885

# %%
ser['Amazon']= 1.8

# %%
ser
# Out:
# Amazon       1.800000
# Google       0.736408
# Microsoft    1.094814
# Apple        0.520416
# Name: daily returns, dtype: float64

# %%
df = pd.read_csv('https://github.com/QuantEcon/QuantEcon.lectures.code/raw/master/pandas/data/test_pwt.csv')

# %%
df
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[2:5]
# Out:
#   country country isocode  year          POP       XRAT         tcgdp  \
# 2   India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3  Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4  Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
#
#           cc         cg
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954

# %%
df[['year','country']]
# Out:
#    year        country
# 0  2000      Argentina
# 1  2000      Australia
# 2  2000          India
# 3  2000         Israel
# 4  2000         Malawi
# 5  2000   South Africa
# 6  2000  United States
# 7  2000        Uruguay

# %%
df.iloc[2:5,0:3]
# Out:
#   country country isocode  year
# 2   India             IND  2000
# 3  Israel             ISR  2000
# 4  Malawi             MWI  2000

# %%
df.loc[df.index[2:5],['country']]
# Out:
#   country
# 2   India
# 3  Israel
# 4  Malawi

# %%
df[['country','year','POP']]
# Out:
#          country  year          POP
# 0      Argentina  2000    37335.653
# 1      Australia  2000    19053.186
# 2          India  2000  1006300.297
# 3         Israel  2000     6114.570
# 4         Malawi  2000    11801.505
# 5   South Africa  2000    45064.098
# 6  United States  2000   282171.957
# 7        Uruguay  2000     3219.793

# %%
df.set_index('country')
# Out:
#               country isocode  year          POP       XRAT         tcgdp  \
# country
# Argentina                 ARG  2000    37335.653   0.999500  2.950722e+05
# Australia                 AUS  2000    19053.186   1.724830  5.418047e+05
# India                     IND  2000  1006300.297  44.941600  1.728144e+06
# Israel                    ISR  2000     6114.570   4.077330  1.292539e+05
# Malawi                    MWI  2000    11801.505  59.543808  5.026222e+03
# South Africa              ZAF  2000    45064.098   6.939830  2.272424e+05
# United States             USA  2000   282171.957   1.000000  9.898700e+06
# Uruguay                   URY  2000     3219.793  12.099592  2.525596e+04
#
#                       cc         cg
# country
# Argentina      75.716805   5.578804
# Australia      67.759026   6.720098
# India          64.575551  14.072206
# Israel         64.436451  10.266688
# Malawi         74.707624  11.658954
# South Africa   72.718710   5.726546
# ...

# %%
df.columns = 'country','countrycode','year','POP','XRAT','tcgdp','cc','cg'

# %%
df
# Out:
#          country countrycode  year          POP       XRAT         tcgdp  \
# 0      Argentina         ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia         AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India         IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel         ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi         MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa         ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States         USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay         URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df.rename(index=str,columns={'year':'Period','POP':"Population",'XRAT':"Strange Rate"})
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    37335.653      0.999500  2.950722e+05
# 1      Australia         AUS    2000    19053.186      1.724830  5.418047e+05
# 2          India         IND    2000  1006300.297     44.941600  1.728144e+06
# 3         Israel         ISR    2000     6114.570      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    11801.505     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    45064.098      6.939830  2.272424e+05
# 6  United States         USA    2000   282171.957      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     3219.793     12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df = df.rename(index=str,columns={'year':'Period','POP':"Population",'XRAT':"Strange Rate"})

# %%
df['Population'] = df['Population']*10

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df['GDP percap'] = df['tcgdp']*1e6/df['Population']

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804  7.903229e+05
# 1  67.759026   6.720098  2.843643e+06
# 2  64.575551  14.072206  1.717325e+05
# 3  64.436451  10.266688  2.113867e+06
# 4  74.707624  11.658954  4.258967e+04
# ...

# %%
df['GDP percap']=df['GDP percap']/1e3

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg   GDP percap
# 0  75.716805   5.578804   790.322908
# 1  67.759026   6.720098  2843.643326
# 2  64.575551  14.072206   171.732472
# 3  64.436451  10.266688  2113.867275
# 4  74.707624  11.658954    42.589668
# 5  72.718710   5.726546   504.264769
# ...

# %%
df['GDP percap']=df['GDP percap']*1e3

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804  7.903229e+05
# 1  67.759026   6.720098  2.843643e+06
# 2  64.575551  14.072206  1.717325e+05
# 3  64.436451  10.266688  2.113867e+06
# 4  74.707624  11.658954  4.258967e+04
# ...

# %%
df['GDP percap']=df['GDP percap']/1e2

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804   7903.229085
# 1  67.759026   6.720098  28436.433261
# 2  64.575551  14.072206   1717.324719
# 3  64.436451  10.266688  21138.672749
# 4  74.707624  11.658954    425.896679
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df['GDP percap'].plot(kind='bar')
plt.show()

# %%
df = df.sort_values(by='GDP percap',ascending = False)

# %%
ax = df['GDP percap'].plot(kind='bar')
ax.set_xticklabels(df['country'])
plt.show()

# %%
df.sort_index()
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804   7903.229085
# 1  67.759026   6.720098  28436.433261
# 2  64.575551  14.072206   1717.324719
# 3  64.436451  10.266688  21138.672749
# 4  74.707624  11.658954    425.896679
# ...

# %%
df.sort_values(by='Strange Rate',ascending=True)
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804   7903.229085
# 6  72.347054   6.032454  35080.381854
# 1  67.759026   6.720098  28436.433261
# 3  64.436451  10.266688  21138.672749
# 5  72.718710   5.726546   5042.647686
# ...

# %%
df.sort_index()
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804   7903.229085
# 1  67.759026   6.720098  28436.433261
# 2  64.575551  14.072206   1717.324719
# 3  64.436451  10.266688  21138.672749
# 4  74.707624  11.658954    425.896679
# ...

# %%
df.loc[["2","3","4"],'country']
# Out:
# 2     India
# 3    Israel
# 4    Malawi
# Name: country, dtype: object

# %%
df
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
#
#           cc         cg    GDP percap
# 6  72.347054   6.032454  35080.381854
# 1  67.759026   6.720098  28436.433261
# 3  64.436451  10.266688  21138.672749
# 0  75.716805   5.578804   7903.229085
# 7  78.978740   5.108068   7843.970620
# ...

# %%
df.sort_index()
# Out:
#          country countrycode  Period   Population  Strange Rate         tcgdp  \
# 0      Argentina         ARG    2000    373356.53      0.999500  2.950722e+05
# 1      Australia         AUS    2000    190531.86      1.724830  5.418047e+05
# 2          India         IND    2000  10063002.97     44.941600  1.728144e+06
# 3         Israel         ISR    2000     61145.70      4.077330  1.292539e+05
# 4         Malawi         MWI    2000    118015.05     59.543808  5.026222e+03
# 5   South Africa         ZAF    2000    450640.98      6.939830  2.272424e+05
# 6  United States         USA    2000   2821719.57      1.000000  9.898700e+06
# 7        Uruguay         URY    2000     32197.93     12.099592  2.525596e+04
#
#           cc         cg    GDP percap
# 0  75.716805   5.578804   7903.229085
# 1  67.759026   6.720098  28436.433261
# 2  64.575551  14.072206   1717.324719
# 3  64.436451  10.266688  21138.672749
# 4  74.707624  11.658954    425.896679
# ...

# %%
df.groupby("countrycode")['Population'].mean()
# Out:
# countrycode
# ARG      373356.53
# AUS      190531.86
# IND    10063002.97
# ISR       61145.70
# MWI      118015.05
# URY       32197.93
# USA     2821719.57
# ZAF      450640.98
# Name: Population, dtype: float64

# %%
df.groupby("countrycode")['Population'].mean().plot()
